# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
from secrets import *

# %%
#Authentication
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ### Functions

# %%
def get_features(dataframe, 
                column, 
                links = [],
                danceability = [],
                energy = [],
                loudness = [],
                speechiness = [],
                acousticness = [],
                instrumentalness = [],
                liveness = [],
                valence = [],
                tempo = []):

    for link in dataframe[column]:  
            
             connection = sp.audio_features(link)[0]

             links.append(link)
             danceability.append(connection["danceability"])
             energy.append(connection["energy"])
             loudness.append(connection["loudness"])
             speechiness.append(connection["speechiness"])
             acousticness.append(connection["acousticness"])
             instrumentalness.append(connection["instrumentalness"])
             liveness.append(connection["liveness"])
             valence.append(connection["valence"])
             tempo.append(connection["tempo"])
            
  
    features_df = pd.DataFrame({"song_url": links,
                                "danceability": danceability,
                                "energy": energy,
                                "loudness": loudness,
                                "speechiness": speechiness,
                                "acousticness": acousticness,
                                "instrumentalness": instrumentalness,
                                "liveness": liveness,
                                "valence": valence,
                                "tempo": tempo})
    return features_df

# %% [markdown]
# ### Some custom searching

# %%
name = "070 Shake"
results = sp.search(q='artist:' + "Rex Orange County"+ " track:" + "Loving Is Easy (feat. Benny Sings)", type='track')

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
sp.playlist_tracks(playlist_URI)['items'][1]
# Out:
# {'added_at': '2022-12-16T11:02:52Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lpH0xAS4fVfLkACg9DAuM'},
#      'href': 'https://api.spotify.com/v1/artists/5lpH0xAS4fVfLkACg9DAuM',
#      'id': '5lpH0xAS4fVfLkACg9DAuM',
#      'name': 'Wham!',
#      'type': 'artist',
#      'uri': 'spotify:artist:5lpH0xAS4fVfLkACg9DAuM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6egzU9NKfora01qaNbvwfZ'},
#    'href': 'https://api.spotify.com/v1/albums/6egzU9NKfora01qaNbvwfZ',
#    'id': '6egzU9NKfora01qaNbvwfZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f2d2adaa21ad616df6241e7d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f2d2adaa21ad616df6241e7d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f2d2adaa21ad616df6241e7d',
#      'width': 64}],
#    'name': 'LAST CHRISTMAS',
#    'release_date': '1984-11-29',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:6egzU9NKfora01qaNbvwfZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lpH0xAS4fVfLkACg9DAuM'},
#     'href': 'https://api.spotify.com/v1/artists/5lpH0xAS4fVfLkACg9DAuM',
#     'id': '5lpH0xAS4fVfLkACg9DAuM',
#     'name': 'Wham!',
#     'type': 'artist',
#     'uri': 'spotify:artist:5lpH0xAS4fVfLkACg9DAuM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 262960,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBBM8400019'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2FRnf9qhLbvw8fu4IBXx78'},
#   'href': 'https://api.spotify.com/v1/tracks/2FRnf9qhLbvw8fu4IBXx78',
#   'id': '2FRnf9qhLbvw8fu4IBXx78',
#   'is_local': False,
#   'name': 'Last Christmas',
#   'popularity': 95,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e0977ffe721d032577fa5ae8a82ee79540c26970?cid=e8d5c566e85d43ceae36ccda4235f0f5',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2FRnf9qhLbvw8fu4IBXx78'},
#  'video_thumbnail': {'url': None}}

# %% [markdown]
# ### Downloading characteristics of songs from personal data

# %%
streaming_df = pd.read_csv('spotify_data/streaming_history_concat.csv', index_col=0)

# %%
plays_count = streaming_df.groupby("trackName")['artistName'].count().reset_index()

# %%
streaming_df = streaming_df.drop_duplicates(subset=['trackName'])
streaming_df.shape
# Out:
# (6432, 4)

# %%
streaming_df = streaming_df.merge(plays_count, on="trackName")

# %%
streaming_df = streaming_df.sort_values("artistName_y", ascending=False).iloc[1:200,]

# %%
streaming_df = streaming_df.rename(columns = {"artistName_x": "artistName", "artistName_y": "plays_count"})

# %%
songs_links = []
for index, song in streaming_df.iterrows():
    results = sp.search(q='artist:' + streaming_df["artistName"][index] + " track:" + streaming_df["trackName"][index], type='track')
    items = results['tracks']['items']

    if len(items) != 0:
        try:
            link = items[1]['href']
        except:
            link = items[0]['href']
    else:
        link = ""
    songs_links.append(link)

# %%
streaming_df['song_url'] = songs_links
streaming_df = streaming_df[streaming_df['song_url'] != ""]

# %%
features = get_features(streaming_df, "song_url")
# Out:
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/70AYiGbc4mWZGEqiipBBDb
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6slWOE0SO6HjBH0fNd13YB
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4n1WwhKzKHUX598tvU1wMu
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4Dvkj6JhhA12EX05fT7y2e
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6sQ1IeoCqOF3RjpCitYDWq
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6Ucrht7JfguIXoa4hF9Leo
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4XBIzFEVvF4stC7E6IigLl
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4k6Uh1HXdhtusDW5y8Gbvy
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4ydmav4vl7hebadtfZtMrg
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/0Sso7XxbgfNuNdLJomPzCv
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6ibG3YAgbseFGSrj0gkcyl
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/77VjuBo3CJbamC3gzaUzK9
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4Gn1QTNQReiekDQe4G9Nwn
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/2sm72B1Svh4B83f55D2g0K
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7pYqg3MNepP6efQrXPXJz1
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/0M7leFFa1yqInTOjfIcYgU
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/0HMCdlOPJkAGlB0MlSWIcO
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1yVbARBysb11nskwIzXLIg
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1a8bD4h66dkyLGt6bsCDpL
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/2kyTxBTQtKhTXYBOLkBjs0
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4j6kId9QIqhoXvqHKgSKa0
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7ru8cuW1DyDbcOojKN3NlC
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5S53SWJRG2eLjFeRu8JkE5
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5kUgMxXcpAdsnKumXs4J5Z
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/46oHvXwpEZOFX518we1nJD
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/726LKld6L4bQrj0hB1pDic
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3QEAASlCvfR9LEYIHIJCi6
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5Oh3UvbH41pRuidEQCVkAL
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/69w5X6uTrOaWM32IetSzvO
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6CAXRGPbYPeZY9G0hX3PsH
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1RBDuitibQKdeZOgiebP8X
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3i058E8uxTsYqJ5NWZzqSj
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6X3FZtz4cKU2MKSQlGG9ZG
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7n4YpQcocaRfXRlEl07klO
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6KShrxuBClLqNiB5a3Bjp6
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6meatKYU5FOOkR9iXNPBHz
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3ZOKwVcjcHVNqnOABO0pUA
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/44fJvX18MOEE8TYxxlFoSB
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5urhxXrAA3lyKucdA2Cm5M
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1qEmFfgcLObUfQm0j1W2CK
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4MOy68Xuz84lkfu1NQH6Bg
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4PL1QUjQBMNu2Hc9hiKr80
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3UN7R1teOKhmB8SnxtwiPK
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4RR45jOrKF4jCcyrvP0qyI
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7l26dZs9DhSf8xyJ7NxbuP
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4x37DDVZ6L5MRaWpwFHzWz
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6MpTBrx9i8jA9ntQIfdUqj
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1uULPX0Bvz4ksJRrA2upxu
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5GvS2DPObNz4yPUonWSsX3
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1557pxLGWCKKBtKuiexttX
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7Bpx2vsWfQFBACRz4h3IqH
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7y1r8U18JSN93zZARYKfhT
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/2iqn4H1SVAfsVNKeQYz4V2
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7E66uxFz2NtHWAyiGXotha
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/2QtJA4gbwe1AcanB2p21aP
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5zOqYPTcgiTAZfnKUbaNSf
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/44I7sqKYCAa7bQdVywkShO
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/4OFAQoIz9Q4OaFiyFGSKp1
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/0bt7P4sertYry5PQJ6o0ZO
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5MN4hnNta44Ezm2dfajQB0
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/5W2s4S60GoNsUthU51aUb8
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7v7aWO4Rl8aMTmDNLaQSjT
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6UESYBOQxsUvxpDdBNVDPO
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3lRx4jcfc88j54ZU2h2G60
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3qNf31pEZJRN9FJN1Ax0BJ
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1L0EA6BegmM4KMwTHmSHux
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7Jr5clL1XdDEP5Lkx9I8A5
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/6qopJBPesEVIrIT0qMtbNs
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/1OkRb4h1HdRu45zvGagglu
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/144DzLNGclktTgFxaYds9l
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/7AA6prOzEyZNWTD62vDAsj
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3nLIcMNZcEYLq5aZT4IbAD
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/71ygHdcBa5lLBoEpiFKEPG
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/0u41XvaIm4PXMN43uaZC35
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/3pCkuopR4wBW8PhkLdlKMA
# Expected id of type track but found type tracks https://api.spotify.com/v1/tracks/2rNw9487KHK6dep3r1ZOXT

# %%
features.shape
# Out:
# (198, 10)

# %%
streaming_df = streaming_df.merge(features, on="song_url")
streaming_df = streaming_df.drop(["endTime", "song_url", "sec_played", "plays_count"], axis=1)
streaming_df.to_csv("spotify_data/personal_data_to_recommend")

# %%
streaming_df.head()
# Out:
#      artistName       trackName  danceability  energy  loudness  speechiness  \
# 0       ROSALÍA           CANDY         0.638   0.490    -5.726       0.2260
# 1     070 Shake  Skin and Bones         0.613   0.633    -6.494       0.0292
# 2       ROSALÍA           SAOKO         0.835   0.772    -5.711       0.2470
# 3  Harry Styles       As It Was         0.520   0.731    -5.338       0.0557
# 4     Yung Lean            Trip         0.531   0.906    -6.437       0.0376
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0      0.885000           0.01160    0.1560    0.403  179.905
# 1      0.043900           0.00000    0.0839    0.334  115.980
# 2      0.793000           0.00002    0.5150    0.683  100.034
# 3      0.342000           0.00101    0.3110    0.662  173.930
# 4      0.000922           0.40600    0.1980    0.512  174.006

# %% [markdown]
# ### Building recommendation database

# %%
playlist_URL = "spotify:playlist:54A6wGeGp7yAra5hwK6xHq"

# %%
def call_playlist(creator, playlist_id):

    playlist_features_list = ["artist",
                              "track_name",  
                              "danceability",
                              "energy",
                              "loudness",
                              "speechiness", 
                              "acousticness", 
                              "instrumentalness",
                              "liveness",
                              "valence",
                              "tempo"]
    
    playlist_df = pd.DataFrame(columns = playlist_features_list)

    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:

        # Create empty dict
        playlist_features = {}

        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)

    
    return playlist_df

# %%
first_df = call_playlist("spotify", "spotify:playlist:54A6wGeGp7yAra5hwK6xHq")
second_df = call_playlist("spotify", "spotify:playlist:3IsxzDS04BvejFJcQ0iVyW")
third_df = call_playlist("spotify", "spotify:playlist:37i9dQZEVXcEQgVh36QNFV")
fourth_df = call_playlist("spotify", "spotify:playlist:37i9dQZF1DX0YKekzl0blG")
fifth_df = call_playlist("spotify", "spotify:playlist:37i9dQZF1DX0YKekzl0blG")
sixth_df = call_playlist("spotify", "spotify:playlist:1coYrjao0tn6XY4HA6AXWV")
recommender_df = pd.concat([first_df, second_df, third_df, fourth_df, fifth_df, sixth_df], axis=0)

# %%
recommender_df.head()
# Out:
#            artist              track_name danceability energy  loudness  \
# 0  Sufjan Stevens              Back To Oz          NaN    NaN   -10.461
# 1      black midi           Diamond Stuff          NaN    NaN   -14.987
# 2      black midi               Dethroned          NaN    NaN    -8.605
# 3  Sufjan Stevens  Lady Macbeth In Chains          NaN    NaN   -13.346
# 4      Dean Blunt                  WOOSAH          NaN    NaN   -13.929
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0314         0.528          0.001180    0.1310    0.441  170.068
# 1       0.0274         0.287          0.926000    0.1460    0.105  134.984
# 2       0.0712         0.130          0.549000    0.6400    0.232  144.909
# 3       0.0526         0.912          0.000734    0.0872    0.134  204.157
# 4       0.0305         0.544          0.869000    0.1040    0.160  147.895
#
#                album                track_id
# 0  A Beginner's Mind  6s0F09N7jp4wSqN8vVgMQR
# 1          Cavalcade  1oqeQqO2AWG0uyPZbGlqXt
# 2          Cavalcade  2tk6DxeaWPqjidof2LtGcL
# 3  A Beginner's Mind  0W2a7Ga9auLPDDPQp11iDO
# 4      BLACK METAL 2  5eKOyf0i14QZHCD6mbwkej

# %%
recommender_df.to_csv("spotify_data/playlists_data_to_recommend.csv")
